# %% [markdown]
# CETAM - IBC - Curso Técnico em Nível Médio em Inteligência Artificial
#
# Manaus, 24 de Março de 2026
#
# Turma : Matutino
#
# Alunas: Pauliana

# %%
print("Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1")
# Out:
# Curso Técnico em Nível Médio de Inteligência Artificial - Turma 2026.1

# %%
nu1 = 0
nu2 = 0
print('ola mundo!')

print(5+5-2)
print(nu1)
print(5**2)
print(nu2)
# Out:
# ola mundo!
# 8
# 0
# 25
# 0

# %%
# Script 1
# Função criada pelo usuario
def dobro(x):
  print(x * 2)

dobro (125)
# Out:
# 250

# %% [markdown]
# CETAM - IBC - Curso Técnico em Nível Médio em Inteligência Artificial
#
# Manaus, 23 de Março de 2026
#
# Turma : Matutino
#
# Alunas: Pauliana

# %%
print ("olá mundo")
# Out:
# olá mundo

# %%
2 + 3
# Out:
# 5

# %%
50 - 5 * 7
# Out:
# 15

# %%
(50 - 5*6)/2
# Out:
# 10.0

# %%
print(8/5) #divisão com operandos inteiros, retorna resultados inteiros
print(8./5) #divisão com pelo menos um operando real, retotrna resultado real (vs.2.7)
# Out:
# 1.6
# 1.6

# %%
5**2 #5 elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin (numero)
print(resultado) # saida "0b111011"
# Out:
# 0b111011

# %%
10 + 50
100 - 20
35 * 2

500 / 20 # resultado final "25.0"
# Out:
# 25.0
